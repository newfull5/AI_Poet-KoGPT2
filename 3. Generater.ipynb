# %% [markdown]
# <a href="https://colab.research.google.com/github/newfull5/AI_Poet-KoGPT2/blob/master/3.%20Generater.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/SKT-AI/KoGPT2.git

# %%
# !cd KoGPT2 && pip install -r requirements.txt
# !cd KoGPT2 && pip install .

# %%
from kogpt2.pytorch_kogpt2 import get_pytorch_kogpt2_model
from gluonnlp.data import SentencepieceTokenizer
from kogpt2.utils import get_tokenizer
from torch.utils.data import DataLoader
import torch

# %%
if torch.cuda.device_count():
  PU = 'cuda'
else:
  PU = 'cpu'

# %%
PU = 'cpu'

# %%
#토큰화와 인덱싱을해서 리턴하는 함수

def dataset (file_path):
  data = []
  tokenizer = SentencepieceTokenizer(get_tokenizer())
  f = open(file_path,'r',encoding='utf-8')

  while True:
    file = f.readline()

    if not file:
      break
    line = tokenizer(file[:-1])
    indexing_word = [vocab[vocab.bos_token]]+ vocab[line] + [vocab[vocab.eos_token]]
    data.append(indexing_word)

  f.close()

  return data

# %%
model, vocab = get_pytorch_kogpt2_model()

load_path = 'drive/My Drive/Colab Notebooks/KoGPT2_checkpoint/KoGPT2_checkpoint.tar'
checkpoint = torch.load(load_path, map_location=torch.device(PU))

model.to(torch.device(PU)) #모델 연산 유닛 설정
torch.load(load_path, map_location=torch.device(PU))

model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

# %%
del model

# %%
#모델 불러오기 코드 입니다
from transformers import GPT2Config, GPT2LMHeadModel

save_path = 'drive/My Drive/Colab Notebooks/KoGPT2_checkpoint/'

kogpt2_config = {
		"initializer_range": 0.02,
		"layer_norm_epsilon": 0.000025,
		"n_ctx": 1024,
		"n_embd": 768,
		"n_head": 12,
		"n_layer": 12,
		"n_positions": 1024,
		"vocab_size": 50000
}

checkpoint = torch.load(save_path+'KoGPT2_checkpoint.tar', map_location=PU)

kogpt2model = GPT2LMHeadModel(config=GPT2Config.from_dict(kogpt2_config))

kogpt2model.load_state_dict(checkpoint['model_state_dict'])

kogpt2model.eval()

kogpt2model.to(torch.device(PU))

model = kogpt2model

# %%
Tokenizer = SentencepieceTokenizer(get_tokenizer(), num_best=0, alpha=0)
# Out:
# using cached model

# %%
sentence = '세상'
toked = Tokenizer(sentence)
temp = []
cnt = 0
while True:
  input_ids = torch.tensor([vocab[vocab.bos_token],] + vocab[toked]).unsqueeze(0)
  pred = model(input_ids)[0]

  gen = vocab.to_tokens(torch.argmax(pred, axis=-1).squeeze().tolist())
  print(gen)
  print(gen[-1])
  gen = gen[-1]
  cnt += 1

  if cnt == 50:
    break

  if '</s>' == gen:
    break
  sentence += gen.replace('▁', ' ')
  toked = Tokenizer(sentence)

print(sentence)
# Out:
# ['▁그', '▁사람들의']
# ▁사람들의
# ['▁그', '▁사람들의', '▁그']
# ▁그
# ['▁그', '▁사람들의', '▁그', '▁말']
# ▁말
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑']
# ▁사랑
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도']
# 이라고도
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부']
# ▁부
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디']
# 디
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀']
# ▁말씀
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해']
# 해
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시']
# ▁주시
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요']
# 어요
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지']
# ▁가지
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마']
# ▁마
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고']
# 라고
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손']
# ▁손
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓']
# 짓
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해']
# 해
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시']
# ▁주시
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요']
# 어요
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달']
# ▁한달
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전']
# ▁전
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난']
# ▁떠난
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이']
# ▁겨울이
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한']
# ▁착한
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가']
# ▁여자가
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못']
# ▁못
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다']
# ▁된다
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망']
# ▁소망
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는']
# 하는
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자']
# ▁여자
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도']
# 도
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못']
# ▁못
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다']
# ▁된다
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물']
# ▁우물
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁']
# 곁
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에']
# 에
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목']
# ▁목
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라']
# 말라
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는']
# ▁죽는
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에']
# ▁마음에
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답']
# ▁대답
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는']
# 하는
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음']
# ▁마음
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼']
# ▁영혼
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에']
# 에
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에', '▁산']
# ▁산
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에', '▁산', '울림']
# 울림
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에', '▁산', '울림', '하는']
# 하는
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에', '▁산', '울림', '하는', '▁영혼']
# ▁영혼
# ['▁그', '▁사람들의', '▁그', '▁말', '▁사랑', '이라고도', '▁부', '디', '▁말씀', '해', '▁주시', '어요', '▁가지', '▁마', '라고', '▁손', '짓', '해', '▁주시', '어요', '▁한달', '▁전', '▁떠난', '▁겨울이', '▁착한', '▁여자가', '▁못', '▁된다', '▁소망', '하는', '▁여자', '도', '▁못', '▁된다', '▁우물', '곁', '에', '▁목', '말라', '▁죽는', '▁마음에', '▁대답', '하는', '▁마음', '▁영혼', '에', '▁산', '울림', '하는', '▁영혼', '▁이를']
# ▁이를
# 세상 사람들의 그 말 사랑이라고도 부디 말씀해 주시어요 가지 마라고 손짓해 주시어요 한달 전 떠난 겨울이 착한 여자가 못 된다 소망하는 여자도 못 된다 우물곁에 목말라 죽는 마음에 대답하는 마음 영혼에 산울림하는 영혼
