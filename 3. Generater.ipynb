# %% [markdown]
# <a href="https://colab.research.google.com/github/newfull5/AI_Poet-KoGPT2/blob/master/3.%20Generater.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/SKT-AI/KoGPT2.git

# %%
# !cd KoGPT2 && pip install -r requirements.txt
# !cd KoGPT2 && pip install .

# %%
from kogpt2.pytorch_kogpt2 import get_pytorch_kogpt2_model
from gluonnlp.data import SentencepieceTokenizer
from kogpt2.utils import get_tokenizer
from torch.utils.data import DataLoader
import torch

# %%
if torch.cuda.device_count():
  PU = 'cuda'
else:
  PU = 'cpu'

# %%
PU = 'cpu'

# %%
#토큰화와 인덱싱을해서 리턴하는 함수

def dataset (file_path):
  data = []
  tokenizer = SentencepieceTokenizer(get_tokenizer())
  f = open(file_path,'r',encoding='utf-8')

  while True:
    file = f.readline()

    if not file:
      break
    line = tokenizer(file[:-1])
    indexing_word = [vocab[vocab.bos_token]]+ vocab[line] + [vocab[vocab.eos_token]]
    data.append(indexing_word)

  f.close()

  return data

# %%
model, vocab = get_pytorch_kogpt2_model()

load_path = 'drive/My Drive/Colab Notebooks/KoGPT2_checkpoint/KoGPT2_checkpoint.tar'
checkpoint = torch.load(load_path, map_location=torch.device(PU))

model.to(torch.device(PU)) #모델 연산 유닛 설정
torch.load(load_path, map_location=torch.device(PU))

model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

# %%
del model

# %%
#모델 불러오기 코드 입니다
from transformers import GPT2Config, GPT2LMHeadModel

save_path = 'drive/My Drive/Colab Notebooks/KoGPT2_checkpoint/'

kogpt2_config = {
		"initializer_range": 0.02,
		"layer_norm_epsilon": 0.000025,
		"n_ctx": 1024,
		"n_embd": 768,
		"n_head": 12,
		"n_layer": 12,
		"n_positions": 1024,
		"vocab_size": 50000
}

checkpoint = torch.load(save_path+'KoGPT2_checkpoint.tar', map_location=PU)

kogpt2model = GPT2LMHeadModel(config=GPT2Config.from_dict(kogpt2_config))

kogpt2model.load_state_dict(checkpoint['model_state_dict'])

kogpt2model.eval()

kogpt2model.to(torch.device(PU))

model = kogpt2model

# %%
Tokenizer = SentencepieceTokenizer(get_tokenizer(), num_best=0, alpha=0)
# Out:
# using cached model

# %%
sentence = '후회'
toked = Tokenizer(sentence)
temp = []
cnt = 0
while True:
  input_ids = torch.tensor([vocab[vocab.bos_token],] + vocab[toked]).unsqueeze(0)
  pred = model(input_ids)[0]

  gen = vocab.to_tokens(torch.argmax(pred, axis=-1).squeeze().tolist())
  print(gen)
  print(gen[-1])
  gen = gen[-1]
  cnt += 1

  if cnt == 50:
    break

  if '</s>' == gen:
    break
  sentence += gen.replace('▁', ' ')
  toked = Tokenizer(sentence)

print(sentence)
# Out:
# ['▁그', '도']
# 도
# ['▁그', '도', '▁하']
# ▁하
# ['▁그', '도', '▁하', '련']
# 련
# ['▁그', '도', '▁하', '련', '만']
# 만
# ['▁그', '도', '▁하', '련', '만', '▁무엇']
# ▁무엇
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에']
# 에
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고']
# ▁걸고
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야']
# ▁살아야
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지']
# ▁할지
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물']
# ▁빗물
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은']
# 같은
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의']
# ▁우리의
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑']
# ▁사랑
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로']
# 으로
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를']
# ▁나를
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채']
# ▁채
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다']
# 운다
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회']
# ▁후회
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도']
# 도
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하']
# ▁하
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련']
# 련
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만']
# 만
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇']
# ▁무엇
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에']
# 에
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고']
# ▁걸고
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야']
# ▁살아야
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지']
# ▁할지
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞']
# ▁앞
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은']
# 날은
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱']
# ▁더욱
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르']
# ▁모르
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노']
# 노
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라']
# 라
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은']
# ▁맑은
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날']
# ▁날
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살']
# ▁햇살
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에']
# 에
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝']
# ▁반짝
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는']
# 이는
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의']
# ▁당신의
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물']
# ▁물
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛']
# 빛
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',']
# ,
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의']
# ▁나의
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨']
# ▁한숨
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨', '▁한']
# ▁한
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨', '▁한', '▁방울']
# ▁방울
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨', '▁한', '▁방울', ',']
# ,
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨', '▁한', '▁방울', ',', '▁당신의']
# ▁당신의
# ['▁그', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁빗물', '같은', '▁우리의', '▁사랑', '으로', '▁나를', '▁채', '운다', '▁후회', '도', '▁하', '련', '만', '▁무엇', '에', '▁걸고', '▁살아야', '▁할지', '▁앞', '날은', '▁더욱', '▁모르', '노', '라', '▁맑은', '▁날', '▁햇살', '에', '▁반짝', '이는', '▁당신의', '▁물', '빛', ',', '▁나의', '▁한숨', '▁한', '▁방울', ',', '▁당신의', '▁그것']
# ▁그것
# 후회도 하련만 무엇에 걸고 살아야 할지 빗물같은 우리의 사랑으로 나를 채운다 후회도 하련만 무엇에 걸고 살아야 할지 앞날은 더욱 모르노라 맑은 날 햇살에 반짝이는 당신의 물빛, 나의 한숨 한 방울, 당신의
